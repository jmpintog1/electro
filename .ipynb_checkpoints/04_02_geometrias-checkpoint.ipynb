# %% [markdown]
# # 4.2 Cálculo de Capacitancia
#
# Para calcular la capacitancia de un arreglo geométrico, generalmente asumimos una carga $Q$, calculamos el campo eléctrico $\vec{E}$ mediante la ley de Gauss, determinamos la diferencia de potencial $\Delta V = -\int \vec{E} \cdot d\vec{l}$ y finalmente aplicamos la definición $C = Q / \Delta V$.
#
# ## Condensador esférico
#
# Consideremos dos cascarones esféricos conductores concéntricos de radios $a$ (interno) y $b$ (externo).

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/04_02.svg
# :alt: Condensador esférico
# :width: 40%
# :align: center
# ```
# &nbsp;

# %%
import numpy as np
import plotly.graph_objects as go

# Función geométrica para crear una esfera (superficie)
def crear_esfera(radio, resolucion=50):
    # Generar la rejilla esférica (phi: [0, pi], theta: [0, 2*pi])
    phi = np.linspace(0, np.pi, resolucion)
    theta = np.linspace(0, 2 * np.pi, resolucion)
    phi_grid, theta_grid = np.meshgrid(phi, theta)
    
    # Coordenadas cartesianas
    x = radio * np.sin(phi_grid) * np.cos(theta_grid)
    y = radio * np.sin(phi_grid) * np.sin(theta_grid)
    z = radio * np.cos(phi_grid)
    return x, y, z

# --- PARÁMETROS INICIALES ---
# Define los radios (asegúrate de que rext > rint)
r_interior = 2.0  # Esfera interior sólida
r_exterior = 3.5  # Cascarón exterior translúcido

# Generar coordenadas para ambas esferas
x_int, y_int, z_int = crear_esfera(r_interior)
x_ext, y_ext, z_ext = crear_esfera(r_exterior)

# Crear la figura interactiva 3D
fig = go.Figure()

# --- AÑADIR SUPERFICIES ---

# 1. Esfera Interior (Sólida - ej. Cobre/Naranja)
fig.add_trace(go.Surface(
    x=x_int, y=y_int, z=z_int,
    colorscale='Oranges', # Estilo visual 'cobre'
    showscale=False,
    opacity=1.0,         # Completamente opaca
    name='Esfera Interior Sólida'
))

# 2. Cascarón Exterior (Translúcido - ej. Malla/Gris)
fig.add_trace(go.Surface(
    x=x_ext, y=y_ext, z=z_ext,
    colorscale='Greys',   # Estilo visual 'malla metálica'
    showscale=False,
    opacity=0.3,         # Baja opacidad para ver el interior
    name='Cascarón Translúcido'
))

# --- AJUSTES DE DISEÑO Y PROPORCIÓN ---
fig.update_layout(
    title=f'Visualización de Cascarón Esférico (r₁={r_interior}, r₂={r_exterior})',
    scene=dict(
        xaxis_title='Eje X',
        yaxis_title='Eje Y',
        zaxis_title='Eje Z',
        aspectmode='data' # CRÍTICO: Mantiene la proporción geométrica real 1:1:1
    ),
    margin=dict(l=0, r=0, b=0, t=40)
)

# Mostrar la visualización interactiva
fig.show()
# Out:
# <div>                            <div id="11340290-9431-46f1-aa26-fea99e88c235" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11340290-9431-46f1-aa26-fea99e88c235")) {                    Plotly.newPlot(                        "11340290-9431-46f1-aa26-fea99e88c235",                        [{"colorscale":[[0.0,"rgb(255,245,235)"],[0.125,"rgb(254,230,206)"],[0.25,"rgb(253,208,162)"],[0.375,"rgb(253,174,107)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(241,105,19)"],[0.75,"rgb(217,72,1)"],[0.875,"rgb(166,54,3)"],[1.0,"rgb(127,39,4)"]],"name":"Esfera Interior S\u00f3lida","opacity":1.0,"showscale":false,"x":[[0.0,0.12814043996142582,0.255754323369012,0.3823172574027446,0.5073091678190147,0.6302164360472413,0.7505340097587482,0.8677674782351162,0.9814351040078757,1.0910698024210972,1.1962210609824317,1.2964567906155768,1.3913651012069728,1.4805559941506308,1.5636629649360594,1.6403445091939117,1.7102855260106922,1.773198612746,1.8288252460316248,1.8769368440995207,1.9173357060733212,1.9498558243636472,1.9743635668289004,1.9907582258983965,1.9989724324013758,1.9989724324013758,1.9907582258983965,1.9743635668289004,1.9498558243636472,1.9173357060733214,1.8769368440995209,1.828825246031625,1.7731986127460002,1.7102855260106924,1.6403445091939122,1.5636629649360598,1.4805559941506314,1.391365101206973,1.2964567906155775,1.1962210609824322,1.091069802421098,0.9814351040078763,0.8677674782351165,0.750534009758749,0.6302164360472416,0.5073091678190156,0.3823172574027451,0.255754323369013,0.12814043996142646,2.4492935982947064e-16],[0.0,0.12708840872065935,0.25365458390950735,0.3791784380043336,0.5031441665638801,0.6250423678189304,0.7443721359134452,0.8606431192341694,0.9733775353705901,1.0821121344253464,1.1864001026074242,1.2858128982858643,1.379942012959246,1.468400649904744,1.5508253136088324,1.6268773034483157,1.6962441054838422,1.7586406766467162,1.8138106160420067,1.8615272185548237,1.9015944064302626,1.9338475349989588,1.9581540692373487,1.9744141283825116,1.9825608963636485,1.9825608963636485,1.9744141283825116,1.9581540692373487,1.9338475349989588,1.9015944064302628,1.861527218554824,1.8138106160420069,1.7586406766467164,1.6962441054838424,1.6268773034483162,1.5508253136088328,1.4684006499047446,1.3799420129592461,1.285812898285865,1.1864001026074247,1.0821121344253473,0.9733775353705907,0.8606431192341696,0.744372135913446,0.6250423678189307,0.503144166563881,0.3791784380043341,0.25365458390950835,0.12708840872066,2.4291849317098954e-16],[0.0,0.12394958932224837,0.2473898431948681,0.3698135191368452,0.49071755200393785,0.6096051211912615,0.7259876921757219,0.8393870240091608,0.9493371345129937,1.0553862150989362,1.1570984873474037,1.2540559937145142,1.345860315009284,1.4321342075835486,1.5125231535070283,1.5866968173575489,1.6543504036401468,1.715205909257139,1.7690132658824798,1.815551367546154,1.854628979206034,1.8860855225736881,1.9097917359650107,1.9256502054642106,1.9335957652184843,1.9335957652184843,1.9256502054642106,1.9097917359650107,1.8860855225736881,1.8546289792060342,1.8155513675461543,1.76901326588248,1.7152059092571392,1.654350403640147,1.5866968173575493,1.5125231535070287,1.432134207583549,1.3458603150092843,1.2540559937145148,1.1570984873474042,1.055386215098937,0.9493371345129943,0.839387024009161,0.7259876921757227,0.6096051211912619,0.4907175520039387,0.3698135191368457,0.24738984319486906,0.12394958932224899,2.3691891157048496e-16],[0.0,0.11877552109393741,0.23706296809443048,0.35437627250917636,0.47023336880670985,0.5841581753270754,0.6956825506034863,0.8043482170560284,0.9097086441525357,1.011330883298328,1.1087973469148533,1.2017075243966207,1.2896796278951865,1.3723521611673182,1.4493854050405983,1.520462813392372,1.5852923139056658,1.6436075082569865,1.6951687668041742,1. ...

# %% [markdown]
# La diferencia de potencial es:
#
# $$\Delta V = -\int_{b}^{a} \frac{Q}{4\pi\epsilon_0 r^2} \hat{r} \cdot dr\hat{r} = \frac{Q}{4\pi\epsilon_0} \left( \frac{1}{a} - \frac{1}{b} \right) = \frac{Q}{4\pi\epsilon_0} \frac{(b-a)}{ab}$$
#
# Aplicando la definición de capacitancia, obtenemos:
#
# $$C_{\text{esférico}} = \frac{Q}{\Delta V} = 4\pi\epsilon_0 \frac{ab}{(b-a)}$$
#
# ## Condensador cilíndrico
#
# Para un arreglo de dos cilindros coaxiales de longitud $L$ y radios $a$ y $b$ ($L \gg b$), el campo eléctrico en la región intermedia es $\vec{E} = \frac{Q/L}{2\pi\epsilon_0 r}\hat{r}$.

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/04_03.svg
# :alt: Condensador cilíndrico
# :width: 40%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/04_02.svg
# :alt: Vista superior
# :width: 40%
# :align: center
# ```
# &nbsp;

# %%
from IPython.display import display, HTML

simulacion_condensador_html = """
<div style="border: 1px solid #e0e0e0; padding: 20px; border-radius: 8px; background-color: #f8f9fa; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Arial, sans-serif;">
    <h3 style="margin-top:0; color: #2c3e50;">Simulación 2D: Condensador Cilíndrico (Vista Transversal)</h3>
    <p style="font-size: 0.95em; color: #555; margin-bottom: 15px;">Modifica los radios para observar cómo cambia la densidad de las líneas de campo eléctrico y la capacitancia del sistema.</p>
    
    <div style="display: flex; gap: 20px; flex-wrap: wrap; margin-bottom: 15px;">
        <div style="flex: 1; min-width: 250px;">
            <div style="margin-bottom: 8px;">
                <label style="font-weight: 600; display: inline-block; width: 160px; color: #dc3545;">Radio interior a (mm): <span id="cond_val_a" style="font-weight: normal;">5</span></label>
                <input type="range" id="cond_slider_a" min="1" max="15" step="0.5" value="5" style="width: 45%; vertical-align: middle;">
            </div>
            <div>
                <label style="font-weight: 600; display: inline-block; width: 160px; color: #0d6efd;">Radio exterior b (mm): <span id="cond_val_b" style="font-weight: normal;">15</span></label>
                <input type="range" id="cond_slider_b" min="5" max="30" step="0.5" value="15" style="width: 45%; vertical-align: middle;">
            </div>
        </div>

        <div style="flex: 1; min-width: 250px; font-size: 0.95em; background: #fff; padding: 10px; border-radius: 6px; border: 1px solid #ccc;">
            <div style="margin-bottom: 5px;"><b>Capacitancia (por metro):</b> <span id="cond_val_C" style="color: #198754; font-weight: bold;">0</span> pF/m</div>
            <div><b>Campo E máx (en r=a):</b> <span id="cond_val_E" style="color: #dc3545; font-weight: bold;">0</span> V/m</div>
            <div style="font-size: 0.8em; color: #777; margin-top: 5px;">*Asumiendo una diferencia de potencial de 10V</div>
        </div>
    </div>
    
    <div style="text-align: center; position: relative;">
        <canvas id="cond_canvas" width="600" height="400" style="background: white; border: 1px solid #ccc; border-radius: 4px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); max-width: 100%;"></canvas>
    </div>
</div>

<script>
    (function() {
        const canvas = document.getElementById('cond_canvas');
        const ctx = canvas.getContext('2d');
        
        const slider_a = document.getElementById('cond_slider_a');
        const slider_b = document.getElementById('cond_slider_b');
        const val_a = document.getElementById('cond_val_a');
        const val_b = document.getElementById('cond_val_b');
        const val_C = document.getElementById('cond_val_C');
        const val_E = document.getElementById('cond_val_E');
        
        const epsilon_0 = 8.854e-12;
        const V = 10; // Voltaje fijo para la simulación

        function drawArrow(fromx, fromy, tox, toy, color, width) {
            ctx.beginPath();
            ctx.moveTo(fromx, fromy);
            ctx.lineTo(tox, toy);
            ctx.strokeStyle = color;
            ctx.lineWidth = width;
            ctx.stroke();

            let angle = Math.atan2(toy - fromy, tox - fromx);
            let dist = Math.hypot(tox - fromx, toy - fromy);
            if (dist < 5) return; 
            
            let headlen = 8;
            ctx.beginPath();
            ctx.moveTo(tox, toy);
            ctx.lineTo(tox - headlen * Math.cos(angle - Math.PI/7), toy - headlen * Math.sin(angle - Math.PI/7));
            ctx.lineTo(tox - headlen * Math.cos(angle + Math.PI/7), toy - headlen * Math.sin(angle + Math.PI/7));
            ctx.lineTo(tox, toy);
            ctx.fillStyle = color;
            ctx.fill();
        }

        function updateSim() {
            let a = parseFloat(slider_a.value);
            let b = parseFloat(slider_b.value);
            
            // Lógica para asegurar que b > a
            if (a >= b) {
                b = a + 1;
                slider_b.value = b;
            }
            
            val_a.innerText = a.toFixed(1);
            val_b.innerText = b.toFixed(1);

            // Cálculos físicos
            let a_m = a / 1000;
            let b_m = b / 1000;
            
            // Capacitancia por unidad de longitud C/L = 2*pi*e0 / ln(b/a)
            let C_L = (2 * Math.PI * epsilon_0) / Math.log(b_m / a_m);
            val_C.innerText = (C_L * 1e12).toFixed(2); // Convertir a pF
            
            // Campo eléctrico máximo E = V / (a * ln(b/a))
            let E_max = V / (a_m * Math.log(b_m / a_m));
            val_E.innerText = E_max.toFixed(0);

            // Dibujo
            ctx.clearRect(0, 0, canvas.width, canvas.height);
            let cx = canvas.width / 2;
            let cy = canvas.height / 2;
            
            // Escala visual (30mm max radius = 180px)
            let scale = 180 / 30; 
            let r_a_px = a * scale;
            let r_b_px = b * scale;

            // Dibujar cilindro exterior (Cátodo)
            ctx.beginPath();
            ctx.arc(cx, cy, r_b_px, 0, 2 * Math.PI);
            ctx.fillStyle = 'rgba(13, 110, 253, 0.1)'; // Azul claro
            ctx.fill();
            ctx.lineWidth = 4;
            ctx.strokeStyle = '#0d6efd';
            ctx.stroke();

            // Dibujar líneas de campo (Vectores)
            let num_lines = 16;
            for(let i = 0; i < num_lines; i++) {
                let angle = (i * 2 * Math.PI) / num_lines;
                
                // Dividimos el espacio en pequeños segmentos para mostrar que la flecha es más grande cerca del centro
                let r_current = a;
                let step = (b - a) / 4;
                
                for(let j=0; j<4; j++) {
                    let r1 = r_current;
                    let r2 = r_current + step * 0.7; // El 0.7 deja un pequeño espacio entre flechas
                    
                    let E_mag = 1 / r1; // Relación proporcional inversa
                    let arrow_width = Math.max(1, E_mag * a * 2); // Grosor depende de la magnitud
                    let alpha = Math.max(0.2, E_mag * a); // Opacidad depende de la magnitud
                    
                    let x1 = cx + r1 * scale * Math.cos(angle);
                    let y1 = cy + r1 * scale * Math.sin(angle);
                    let x2 = cx + r2 * scale * Math.cos(angle);
                    let y2 = cy + r2 * scale * Math.sin(angle);
                    
                    drawArrow(x1, y1, x2, y2, `rgba(44, 62, 80, ${alpha})`, arrow_width);
                    r_current += step;
                }
            }

            // Dibujar cilindro interior (Ánodo)
            ctx.beginPath();
            ctx.arc(cx, cy, r_a_px, 0, 2 * Math.PI);
            ctx.fillStyle = '#dc3545'; // Rojo sólido
            ctx.fill();
            ctx.lineWidth = 2;
            ctx.strokeStyle = '#842029';
            ctx.stroke();
            
            // Etiquetas de cargas
            ctx.fillStyle = 'white';
            ctx.font = 'bold 14px Arial';
            ctx.fillText("+", cx - 4, cy + 5);
            ctx.fillStyle = '#0d6efd';
            ctx.fillText("-", cx + r_b_px + 5, cy + 5);
        }

        slider_a.addEventListener('input', updateSim);
        slider_b.addEventListener('input', updateSim);

        updateSim();
    })();
</script>
"""

display(HTML(simulacion_condensador_html))
# Out:
# <div style="border: 1px solid #e0e0e0; padding: 20px; border-radius: 8px; background-color: #f8f9fa; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Arial, sans-serif;">
#     <h3 style="margin-top:0; color: #2c3e50;">Simulación 2D: Condensador Cilíndrico (Vista Transversal)</h3>
#     <p style="font-size: 0.95em; color: #555; margin-bottom: 15px;">Modifica los radios para observar cómo cambia la densidad de las líneas de campo eléctrico y la capacitancia del sistema.</p>
#
#     <div style="display: flex; gap: 20px; flex-wrap: wrap; margin-bottom: 15px;">
#         <div style="flex: 1; min-width: 250px;">
#             <div style="margin-bottom: 8px;">
#                 <label style="font-weight: 600; display: inline-block; width: 160px; color: #dc3545;">Radio interior a (mm): <span id="cond_val_a" style="font-weight: normal;">5</span></label>
#                 <input type="range" id="cond_slider_a" min="1" max="15" step="0.5" value="5" style="width: 45%; vertical-align: middle;">
#             </div>
#             <div>
#                 <label style="font-weight: 600; display: inline-block; width: 160px; color: #0d6efd;">Radio exterior b (mm): <span id="cond_val_b" style="font-weight: normal;">15</span></label>
#                 <input type="range" id="cond_slider_b" min="5" max="30" step="0.5" value="15" style="width: 45%; vertical-align: middle;">
#             </div>
#         </div>
#
#         <div style="flex: 1; min-width: 250px; font-size: 0.95em; background: #fff; padding: 10px; border-radius: 6px; border: 1px solid #ccc;">
#             <div style="margin-bottom: 5px;"><b>Capacitancia (por metro):</b> <span id="cond_val_C" style="color: #198754; font-weight: bold;">0</span> pF/m</div>
#             <div><b>Campo E máx (en r=a):</b> <span id="cond_val_E" style="color: #dc3545; font-weight: bold;">0</span> V/m</div>
#             <div style="font-size: 0.8em; color: #777; margin-top: 5px;">*Asumiendo una diferencia de potencial de 10V</div>
#         </div>
#     </div>
#
#     <div style="text-align: center; position: relative;">
#         <canvas id="cond_canvas" width="600" height="400" style="background: white; border: 1px solid #ccc; border-radius: 4px; box-shadow: 0 2px 5px rgba(0,0,0,0.05); max-width: 100%;"></canvas>
#     </div>
# </div>
#
# <script>
#     (function() {
#         const canvas = document.getElementById('cond_canvas');
#         const ctx = canvas.getContext('2d');
#
#         const slider_a = document.getElementById('cond_slider_a');
#         const slider_b = document.getElementById('cond_slider_b');
#         const val_a = document.getElementById('cond_val_a');
#         const val_b = document.getElementById('cond_val_b');
#         const val_C = document.getElementById('cond_val_C');
#         const val_E = document.getElementById('cond_val_E');
#
#         const epsilon_0 = 8.854e-12;
#         const V = 10; // Voltaje fijo para la simulación
#
#         function drawArrow(fromx, fromy, tox, toy, color, width) {
#             ctx.beginPath();
#             ctx.moveTo(fromx, fromy);
#             ctx.lineTo(tox, toy);
#             ctx.strokeStyle = color;
#             ctx.lineWidth = width;
#             ctx.stroke();
#
#             let angle = Math.atan2(toy - fromy, tox - fromx);
#             let dist = Math.hypot(tox - fromx, toy - fromy);
#             if (dist < 5) return;
#
#             let headlen = 8;
#             ctx.beginPath();
#             ctx.moveTo(tox, toy);
#             ctx.lineTo(tox - headlen * Math.cos(angle - Math.PI/7), toy - headlen * Math.sin(angle - Math.PI/7));
#             ctx.lineTo(tox - headlen * Math.cos(angle + Math.PI/7), toy - headlen * Math.sin(angle + Math.PI/7));
#             ctx.lineTo(tox, toy);
#             ctx.fillStyle = color;
#             ctx.fill();
#         }
#
#         function updateSim() {
#             let a = parseFloat(slider_a.value);
#             let b = parseFloat(slider_b.value);
#
#             // Lógica para asegurar que b > a
#             if (a >= b) {
#                 b = a + 1;
#                 slider_b.value = b;
#             }
#
#             val_a.innerText = a.toFixed(1);
#             val_b.innerText = b.toFixed(1);
#
#             // Cálculos físicos
#             let a_m = a / 1000;
#             let b_m = b / 1000;
#
#             // Capacitancia por unidad de longitud C/L = 2*pi*e0 / ln(b/a)
#             let C_L = (2 * Math.PI * epsilon_0) / Math.log(b_m / a_m);
#             val_C.innerText = (C_L * 1e12).toFixed(2); // Convertir a pF
#
#             // Campo eléctrico máximo E = V / (a * ln(b/a))
#             let E_max = V / (a_m * Math.log(b_m / a_m));
#             val_E.innerText = E_max.toFixed(0);
#
#             // Dibujo
#             ctx.clearRect(0, 0, canvas.width, canvas.height);
#             let cx = canvas.width / 2;
#             let cy = canvas.height / 2;
#
#             // Escala visual (30mm max radius = 180px)
#             let scale = 180 / 30;
#             let r_a_px = a * scale;
#             let r_b_px = b * scale;
#
#             // Dibujar cilindro exterior (Cátodo)
#             ctx.beginPath();
#             ctx.arc(cx, cy, r_b_px, 0, 2 * Math.PI);
#             ctx.fillStyle = 'rgba(13, 110, 253, 0.1)'; // Azul claro
#             ctx.fill();
#             ctx.lineWidth = 4;
#             ctx.strokeStyle = '#0d6efd';
#             ctx.stroke();
#
#             // Dibujar líneas de campo (Vectores)
#             let num_lines = 16;
#             for(let i = 0; i < num_lines; i++) {
#                 let angle = (i * 2 * Math.PI) / num_lines;
#
#                 // Dividimos el espacio en pequeños segmentos para mostrar que la flecha es más grande cerca del centro
#                 let r_current = a;
#                 let step = (b - a) / 4;
#
#                 for(let j=0; j<4; j++) {
#                     let r1 = r_current;
#                     let r2 = r_current + step * 0.7; // El 0.7 deja un pequeño espacio entre flechas
#
#                     let E_mag = 1 / r1; // Relación proporcional inversa
#                     let arrow_width = Math.max(1, E_mag * a * 2); // Grosor depende de la magnitud
#                     let alpha = Math.max(0.2, E_mag * a); // Opacidad depende de la magnitud
#
#                     let x1 = cx + r1 * scale * Math.cos(angle);
#                     let y1 = cy + r1 * scale * Math.sin(angle);
#                     let x2 = cx + r2 * scale * Math.cos(angle);
#                     let y2 = cy + r2 * scale * Math.sin(angle);
#
#                     drawArrow(x1, y1, x2, y2, `rgba(44, 62, 80, ${alpha})`, arrow_width);
#                     r_current += step;
#                 }
#             }
#
#             // Dibujar cilindro interior (Ánodo)
#             ctx.beginPath();
#             ctx.arc(cx, cy, r_a_px, 0, 2 * Math.PI);
#             ctx.fillStyle = '#dc3545'; // Rojo sólido
#             ctx.fill();
#             ctx.lineWidth = 2;
#             ctx.strokeStyle = '#842029';
#             ctx.stroke();
#
#             // Etiquetas de cargas
#             ctx.fillStyle = 'white';
#             ctx.font = 'bold 14px Arial';
#             ctx.fillText("+", cx - 4, cy + 5);
#             ctx.fillStyle = '#0d6efd';
#             ctx.fillText("-", cx + r_b_px + 5, cy + 5);
#         }
#
#         slider_a.addEventListener('input', updateSim);
#         slider_b.addEventListener('input', updateSim);
#
#         updateSim();
#     })();
# </script>

# %%
import numpy as np
import plotly.graph_objects as go

# Función geométrica para crear los cilindros
def crear_cilindro(radio, longitud, resolucion=50):
    theta = np.linspace(0, 2 * np.pi, resolucion)
    z = np.linspace(0, longitud, 2)
    theta_grid, z_grid = np.meshgrid(theta, z)
    x = radio * np.cos(theta_grid)
    y = radio * np.sin(theta_grid)
    return x, y, z_grid

# Parámetros del cable
longitud_L = 10
radio_interior = 1.0
radio_exterior = 3.0

# Generar coordenadas
x_int, y_int, z_int = crear_cilindro(radio_interior, longitud_L)
x_ext, y_ext, z_ext = crear_cilindro(radio_exterior, longitud_L)

# Crear la figura interactiva
fig = go.Figure()

# Añadir el conductor central (Cobre, opaco)
fig.add_trace(go.Surface(
    x=x_int, y=y_int, z=z_int,
    colorscale='Oranges',
    showscale=False,
    opacity=1.0,
    name='Conductor Central'
))

# Añadir la malla exterior (Gris, translúcida)
fig.add_trace(go.Surface(
    x=x_ext, y=y_ext, z=z_ext,
    colorscale='Greys',
    showscale=False,
    opacity=0.3, # Baja opacidad para ver el interior
    name='Malla Exterior'
))

# Ajustar la vista y proporciones
fig.update_layout(
    title='Sección de Cable Coaxial',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z (Longitud)',
        aspectmode='data' # Mantiene la proporción real de los radios
    ),
    margin=dict(l=0, r=0, b=0, t=40)
)

# Mostrar el resultado
fig.show(renderer="iframe")
# Out:
# <div>                            <div id="0f29a332-913a-4ee6-8018-095aac8aa234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f29a332-913a-4ee6-8018-095aac8aa234")) {                    Plotly.newPlot(                        "0f29a332-913a-4ee6-8018-095aac8aa234",                        [{"colorscale":[[0.0,"rgb(255,245,235)"],[0.125,"rgb(254,230,206)"],[0.25,"rgb(253,208,162)"],[0.375,"rgb(253,174,107)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(241,105,19)"],[0.75,"rgb(217,72,1)"],[0.875,"rgb(166,54,3)"],[1.0,"rgb(127,39,4)"]],"name":"Conductor Central","opacity":1.0,"showscale":false,"x":[[1.0,0.9917900138232462,0.9672948630390295,0.9269167573460217,0.8713187041233894,0.8014136218679567,0.7183493500977277,0.6234898018587336,0.5183925683105252,0.40478334312239395,0.28452758663103267,0.1595998950333793,0.03205157757165533,-0.09602302590768155,-0.22252093395631434,-0.3453650544213075,-0.4625382902408351,-0.5721166601221693,-0.6723008902613165,-0.7614459583691342,-0.8380881048918404,-0.900968867902419,-0.9490557470106686,-0.9815591569910653,-0.9979453927503363,-0.9979453927503363,-0.9815591569910654,-0.9490557470106689,-0.9009688679024191,-0.8380881048918407,-0.7614459583691346,-0.6723008902613171,-0.57211666012217,-0.4625382902408353,-0.34536505442130816,-0.2225209339563146,-0.09602302590768244,0.03205157757165487,0.1595998950333784,0.284527586631032,0.40478334312239295,0.5183925683105245,0.6234898018587334,0.718349350097727,0.8014136218679565,0.871318704123389,0.9269167573460216,0.9672948630390291,0.991790013823246,1.0],[1.0,0.9917900138232462,0.9672948630390295,0.9269167573460217,0.8713187041233894,0.8014136218679567,0.7183493500977277,0.6234898018587336,0.5183925683105252,0.40478334312239395,0.28452758663103267,0.1595998950333793,0.03205157757165533,-0.09602302590768155,-0.22252093395631434,-0.3453650544213075,-0.4625382902408351,-0.5721166601221693,-0.6723008902613165,-0.7614459583691342,-0.8380881048918404,-0.900968867902419,-0.9490557470106686,-0.9815591569910653,-0.9979453927503363,-0.9979453927503363,-0.9815591569910654,-0.9490557470106689,-0.9009688679024191,-0.8380881048918407,-0.7614459583691346,-0.6723008902613171,-0.57211666012217,-0.4625382902408353,-0.34536505442130816,-0.2225209339563146,-0.09602302590768244,0.03205157757165487,0.1595998950333784,0.284527586631032,0.40478334312239295,0.5183925683105245,0.6234898018587334,0.718349350097727,0.8014136218679565,0.871318704123389,0.9269167573460216,0.9672948630390291,0.991790013823246,1.0]],"y":[[0.0,0.127877161684506,0.25365458390950735,0.3752670048793741,0.49071755200393785,0.5981105304912159,0.6956825506034864,0.7818314824680297,0.8551427630053461,0.9144126230158124,0.9586678530366606,0.9871817834144502,0.9994862162006879,0.9953791129491982,0.9749279121818236,0.9384684220497604,0.8865993063730001,0.8201722545969561,0.7402779970753157,0.6482283953077888,0.545534901210549,0.43388373911755823,0.3151082180236208,0.19115862870137254,0.06407021998071323,-0.06407021998071254,-0.19115862870137187,-0.3151082180236202,-0.433883739117558,-0.5455349012105485,-0.6482283953077882,-0.7402779970753153,-0.8201722545969556,-0.8865993063730001,-0.9384684220497602,-0.9749279121818236,-0.9953791129491981,-0.9994862162006879,-0.9871817834144503,-0.9586678530366607,-0.9144126230158128,-0.8551427630053465,-0.7818314824680299,-0.6956825506034869,-0.5981105304912162,-0.49071755200393863,-0.3752670048793746,-0.25365458390950835,-0.12787716168450664,-2.4492935982947064e-16],[0.0,0.127877161684506,0.25365458390950735,0.3752670048793741,0.49071755200393785,0.5981105304912159,0.6956825506034864,0.7818314824680297,0.8551427630053461,0.9144126230158124,0.9586678530366606,0.9871817834144502,0.9994862162006879,0.9953791129491982,0.9749279121818236,0.9384684220497604 ...

# %% [markdown]
# La diferencia de potencial resulta:
#
# $$\Delta V = -\int_{b}^{a} \frac{Q/L}{2\pi\epsilon_0 r} dr = \frac{Q/L}{2\pi\epsilon_0} \ln\left(\frac{b}{a}\right)$$
#
# Por lo tanto, la capacitancia es:
#
# $$C_{\text{cilíndrico}} = \frac{2\pi\epsilon_0 L}{\ln(b/a)}$$
#
# ## Condensador de placas paralelas
#
# Consiste en dos placas metálicas paralelas de área $A$ separadas por una distancia $d$. El campo eléctrico, considerado uniforme entre las placas, tiene una magnitud de $E = \frac{\sigma}{\epsilon_0}$, donde $\sigma = Q/A$.

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/04_04.svg
# :alt: Condensador de placas paralelas
# :width: 40%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/04_05.svg
# :alt: Vista frontal
# :width: 30%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# La diferencia de potencial es simplemente $\Delta V = Ed = \frac{Q}{\epsilon_0 A}d$. La capacitancia es entonces:
#
# $$C_{\text{placas}} = \frac{\epsilon_0 A}{d}$$
