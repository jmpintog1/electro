# %% [markdown]
# # 6.2 Conexiones entre Resistencias
#
# ## Conexión en Serie
#
# Cuando las resistencias se conectan una tras otra, la corriente que fluye a través de ellas es la misma, pero el voltaje total se divide entre cada componente:
# * Corriente: $I = I_1 = I_2$
# * Voltaje: $V = V_1 + V_2$

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/06_03.svg
# :alt: Circuito en serie
# :width: 50%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# Aplicando la Ley de Ohm ($V = I_1R_1 + I_2R_2$), obtenemos que la resistencia equivalente ($R_{eq}$) es la suma algebraica de las resistencias individuales:
#
# $$R_{eq} = \sum_{j=1}^{N} R_j$$
#
# ## Conexión en Paralelo
#
# En una conexión en paralelo, los terminales de las resistencias están conectados a los mismos puntos, por lo que la diferencia de potencial es la misma para todas, pero la corriente total se divide:
# * Voltaje: $V = V_1 = V_2$
# * Corriente: $I = I_1 + I_2$

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/06_04.svg
# :alt: Circuito en paralelo
# :width: 40%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# Al sustituir las corrientes ($I_1 = V/R_1$ y $I_2 = V/R_2$), la resistencia equivalente se calcula mediante la suma de sus inversos:
#
# $$\frac{1}{R_{eq}} = \sum_{j=1}^{N} \frac{1}{R_j}$$
#
# ## Ejemplo 1

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/06_05.svg
# :alt: Ejemplo 1
# :width: 90%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# $$\frac{1}{R_{eq}} = \frac{1}{2R} + \frac{1}{R} + \frac{1}{2R} \Rightarrow R_{eq} = \frac{R}{2}$$
#
# $$I = \frac{2V_0}{R}$$
#
#
# ## Ejemplo 2
#
# Puente de Wheatstone equilibrado.

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/06_06.svg
# :alt: Ejemplo 2
# :width: 90%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# $$\Delta V_{ab} = 0 \Rightarrow I_{ab} = 0$$
#
# $$\frac{1}{R_{eq}} = \frac{1}{2R} + \frac{1}{2R} \Rightarrow R_{eq} = R$$
#
# ## Ejemplo 3
#
# Red simétrica compleja.

# %% [markdown]
# &nbsp;
# ```{image} images_tikz/06_07.svg
# :alt: Ejemplo 3
# :width: 90%
# :align: center
# ```
# &nbsp;

# %% [markdown]
# $$\frac{1}{R_{eq}} = \frac{1}{2R} + \frac{1}{2R} + \frac{1}{R} \Rightarrow R_{eq} = \frac{R}{2}$$
